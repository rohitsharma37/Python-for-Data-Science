# %%
heisenberg_quote = "It ceases to exist without me. No, you clearly don't know who you're talking to, so let me clue you in. I am not in danger, Skyler. I am the danger."
first_letter=[word[0] for word in heisenberg_quote]
print(first_letter)
# Out:
# ['I', 't', ' ', 'c', 'e', 'a', 's', 'e', 's', ' ', 't', 'o', ' ', 'e', 'x', 'i', 's', 't', ' ', 'w', 'i', 't', 'h', 'o', 'u', 't', ' ', 'm', 'e', '.', ' ', 'N', 'o', ',', ' ', 'y', 'o', 'u', ' ', 'c', 'l', 'e', 'a', 'r', 'l', 'y', ' ', 'd', 'o', 'n', "'", 't', ' ', 'k', 'n', 'o', 'w', ' ', 'w', 'h', 'o', ' ', 'y', 'o', 'u', "'", 'r', 'e', ' ', 't', 'a', 'l', 'k', 'i', 'n', 'g', ' ', 't', 'o', ',', ' ', 's', 'o', ' ', 'l', 'e', 't', ' ', 'm', 'e', ' ', 'c', 'l', 'u', 'e', ' ', 'y', 'o', 'u', ' ', 'i', 'n', '.', ' ', 'I', ' ', 'a', 'm', ' ', 'n', 'o', 't', ' ', 'i', 'n', ' ', 'd', 'a', 'n', 'g', 'e', 'r', ',', ' ', 'S', 'k', 'y', 'l', 'e', 'r', '.', ' ', 'I', ' ', 'a', 'm', ' ', 't', 'h', 'e', ' ', 'd', 'a', 'n', 'g', 'e', 'r', '.']

# %% [markdown]
# #### Now let's write a function to do the same
# ### Example 1

# %%
def extract_firstletter(sentence):
    '''
    This funtion takes a sentence as input
    and extracts all the first letters of the words in the sentence. '''
    words_in_sentence=sentence.split(" ")
    first_letters=[word[0] for word in words_in_sentence]
    print(first_letters)

# %%
extract_firstletter(heisenberg_quote)
# Out:
# ['I', 'c', 't', 'e', 'w', 'm', 'N', 'y', 'c', 'd', 'k', 'w', 'y', 't', 't', 's', 'l', 'm', 'c', 'y', 'i', 'I', 'a', 'n', 'i', 'd', 'S', 'I', 'a', 't', 'd']

# %%
heisenber = extract_firstletter(heisenberg_quote) # Even if we are storing this in a variable the function is still printing the output.
                                          # To avoid this use return in place of print
# Out:
# ['I', 'c', 't', 'e', 'w', 'm', 'N', 'y', 'c', 'd', 'k', 'w', 'y', 't', 't', 's', 'l', 'm', 'c', 'y', 'i', 'I', 'a', 'n', 'i', 'd', 'S', 'I', 'a', 't', 'd']

# %% [markdown]
# #### Using Return

# %%
def extract_firstletter(sentence):
    '''
    This funtion takes a sentence as input
    and extracts all the first letters of the words in the sentence. '''
    words_in_sentence=sentence.split(" ")
    first_letters=[word[0] for word in words_in_sentence]
    return first_letters

# %%
heisenberg_letters = extract_firstletter(heisenberg_quote)

# %%
print(heisenberg_letters)
# Out:
# ['I', 'c', 't', 'e', 'w', 'm', 'N', 'y', 'c', 'd', 'k', 'w', 'y', 't', 't', 's', 'l', 'm', 'c', 'y', 'i', 'I', 'a', 'n', 'i', 'd', 'S', 'I', 'a', 't', 'd']

# %% [markdown]
# ### Example 2
# #### Function for factorial

# %%
def factorial(x):
    '''This function returns the factorial of a number'''
    if x<0:
        return "Doesn't Exist"
    elif x>0:
        ans=1
        for i in range(1,x+1):
            ans=ans*i
        return ans
    else:
        return 0

# %%
y=factorial(5)

# %%
z=factorial(0)

# %%
a=factorial(-1)

# %%
print(y)
print(z)
print(a)
# Out:
# 120
# 0
# Doesn't Exist

# %%
factorial(10)
# Out:
# 3628800

# %%
# Now let us define a list of numbers and try to calculate their factorials
def factorial_list(x):
  factorials=[factorial(i) for i in x]
  return factorials

# %%
list_of_numbers = [3, 5, 8, 12, 4, 6]

# %%
factorial_list(list_of_numbers)
# Out:
# [6, 120, 40320, 479001600, 24, 720]

# %% [markdown]
# ##<u> Example 3</u>: Let us write a function which takes a date as a string and prints the quarter as output.
#
# ### Remember it is not required that functions will return a value. This is an example of such functions

# %%
def assignquarter(date):
  ''' This function takes date as input and returns the year and quarter as output'''
  from datetime import datetime
  format="%d-%m-%Y"
  user_date=datetime.strptime(date,format)
  date_month=user_date.month
  date_year=user_date.year
  if date_month>=1 and date_month<=3:
    quarter="Q1"
  elif date_month>3 and date_month<=6:
    quarter="Q2"
  elif date_month>6 and date_month<=9:
    quarter="Q3"
  else:
    quarter="Q4"
  print(f"The given date belongs to the quarter {quarter} from the year {date_year}")

# %%
assignquarter("02-04-1998")
# Out:
# The given date belongs to the quarter Q2 from the year 1998

# %%
assignquarter("01-09-2268")
# Out:
# The given date belongs to the quarter Q3 from the year 2268

# %%
assignquarter("06-11-1864")
# Out:
# The given date belongs to the quarter Q4 from the year 1864

# %% [markdown]
# ##<u> Example 4 </u>: Let us write a function with multiple return statements

# %%
def check_even_odd(num):
  ''' This function checks whether the given number is an even number or an odd number'''
  if num>0 and num%2==0:
    return f"{num} is even"
  elif num>0 and num%2!=0:
    return  f"{num} is odd"
  else:
    return f"{num} is neither even nor odd"

# %%
check_even_odd(5)
# Out:
# '5 is odd'

# %%
check_even_odd(4)
# Out:
# '4 is even'

# %%
check_even_odd(15464)
# Out:
# '15464 is even'

# %%
check_even_odd(0)
# Out:
# '0 is neither even nor odd'

# %% [markdown]
# ## <u> Example 5</u> : Next let us write a function which returns multiple variables at once.
#
# ### In this specific example, the input is a list of numbers. And we have to return the mean and median of this list of numbers

# %%
heights =  [172,175,170,168,170,200]

# %%
def check_averages(my_list):
  ''' This function returns the mean and median of a given list of numbers'''
  #Mean
  mean=sum(my_list)/len(my_list)
  sorted_list=sorted(my_list)
  # Median
  length_list=len(sorted_list)
  if length_list%2==0:
    median= (sorted_list[int(length_list/2)-1]+sorted_list[int(length_list/2)])/2
  else:
    median= sorted[int(length_list/2)-1]
  
  return mean,median

# %%
check_averages(heights)
# Out:
# (175.83333333333334, 171.0)

# %%
mean_heights,median_heights=check_averages(heights)

# %%
print(mean_heights)
print(median_heights)
# Out:
# 175.83333333333334
# 171.0

# %% [markdown]
# ##<u> Example 6</u>: Now let us write a function which adds an element to a list. This functions takes the list as an argument and the element to be added

# %%
def list_append(my_list,elem):
  """This function appends an element to the given list"""
  new_list=my_list+[elem]
  return new_list

# %%
list_append(heights,200)
# Out:
# [172, 175, 170, 168, 170, 200, 200]

# %%
lst=[21,3,6,5]
list_append(heights,lst)
# Out:
# [172, 175, 170, 168, 170, 200, [21, 3, 6, 5]]

# %%
def append_lists(lst1,lst2):
  '''This function appends list to another list without forming nested lists'''
  new_lst=[]
  for i in lst1:
    new_lst.append(i)
  for j in lst2:
    new_lst.append(j)      
  return new_lst

# %%
append_lists(heights,lst)
# Out:
# [172, 175, 170, 168, 170, 200, 21, 3, 6, 5]

# %%
appended_lst=append_lists(heights,lst)
appended_lst
# Out:
# [172, 175, 170, 168, 170, 200, 21, 3, 6, 5]

# %% [markdown]
# ## Let us find out what are the differences between functions and methods
#
# * Function and method both look similar as they perform in an almost similar way, but the key difference is the concept of ‘Class and its Object’. Functions can be called only by its name, as it is defined independently. But methods cannot be called by its name only we need to invoke the class by reference of that class in which it is defined, that is, the method is defined within a class and hence they are dependent on that class.
#
# * A method is called by its name but it is associated with an object (dependent). It is implicitly passed to an object on which it is invoked. It may or may not return any data. A method can operate the data (instance variables) that is contained by the corresponding class.

# %% [markdown]
# # Methods
#
# We've already seen a few example of methods when learning about lists in Python. Methods are essentially functions built into objects.
#
# Methods perform specific actions on an object and can also take arguments, just like a function.
#
# Methods are of the form:
#
#     object.method(arg1,arg2,etc...)

# %%
def insert_value(lst,ind,val):
  '''This function inserts a value to a specified index in a list'''
  first_part=lst[0:ind]
  first_part.append(val)
  last_part=lst[ind:]
  first_part.extend(last_part)
  return first_part

# %%
insert_value(heights,4,169)
# Out:
# [172, 175, 170, 168, 169, 170, 200]
